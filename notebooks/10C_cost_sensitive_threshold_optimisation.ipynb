# %% [markdown]
# # 10C Cost-Sensitive Threshold Optimisation
#
# This notebook turns the final confidence-audit predictions into a deployment-risk threshold study. It does not retrain the model or change the API defaults.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / 'src').exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import OUTPUTS_DIR
from src.evaluation.cost_sensitive_thresholds import export_cost_sensitive_threshold_outputs

OUTPUTS_DIR
# Out:
# WindowsPath('D:/UWE/3rd Year/2nd semester/advanced_ai/ai_system/outputs')

# %%
written = export_cost_sensitive_threshold_outputs()
written
# Out:
# {'cost_sensitive_threshold_results.csv': 'D:\\UWE\\3rd Year\\2nd semester\\advanced_ai\\ai_system\\outputs\\final_evaluation\\cost_sensitive_threshold_results.csv',
#  'cost_sensitive_threshold_summary.json': 'D:\\UWE\\3rd Year\\2nd semester\\advanced_ai\\ai_system\\outputs\\final_evaluation\\cost_sensitive_threshold_summary.json'}

# %%
import json
import pandas as pd

results = pd.read_csv(OUTPUTS_DIR / 'final_evaluation' / 'cost_sensitive_threshold_results.csv')
summary = json.loads((OUTPUTS_DIR / 'final_evaluation' / 'cost_sensitive_threshold_summary.json').read_text())

display(results.sort_values(['expected_operational_cost', 'false_fresh_count', 'manual_review_rate']).head(10))
summary['selected_operating_point']
# Out:
#      confidence_review_threshold  margin_review_threshold  \
# 180                          0.8                     0.00
# 181                          0.8                     0.00
# 182                          0.8                     0.00
# 185                          0.8                     0.05
# 186                          0.8                     0.05
# 187                          0.8                     0.05
# 190                          0.8                     0.10
# 191                          0.8                     0.10
# 192                          0.8                     0.10
# 195                          0.8                     0.15
#
#      rotten_auto_block_threshold  expected_operational_cost  \
# 180                         0.70                   0.111734
# 181                         0.75                   0.111734
# 182                         0.80                   0.111734
# 185                         0.70                   0.111734
# ...

# %% [markdown]
# Report interpretation: the selected operating point minimises expected operational cost under explicit coursework assumptions. Manual review is treated as lower cost than a false-fresh decision, so the study formalises the safety/automation trade-off.
